# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.externals import joblib
import lightgbm as lgb

EXPERIMENT_DIR = 'PATH/TO/YOUR/EXPERIMENT'

# %%
model_filepath = os.path.join(EXPERIMENT_DIR, 'solution_6_best_stacking', 'transformers','light_gbm_fold_0')
light_gbm_model = joblib.load(model_filepath)

# %%
fig, ax = plt.subplots(1,1,figsize=(16,10))
lgb.plot_importance(light_gbm_model, max_num_features=30, ax=ax)
plt.show()

# %%
TREE_INDEX = 0
digraph = lgb.create_tree_digraph(light_gbm_model, tree_index=TREE_INDEX, show_info=['split_gain'])

# %%
digraph
